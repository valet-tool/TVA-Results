# %%
import pandas as pd

# %%
data_MLP = pd.read_csv("predictions_MLP.csv")
data_LSTM = pd.read_csv("predictions_LSTM.csv")
data_SVR_RBF = pd.read_csv("predictions_SVR_RBF.csv")

# %%
data_MLP.head()
# Out:
#       Hours   Minutes   Seconds   Latency  Reliability  TotalCost  Friday  \
# 0  0.565217  0.474576  0.330735  0.015461            1   0.031044       0
# 1  0.565217  0.474576  0.391352  0.031939            1   0.295909       0
# 2  0.565217  0.474576  0.394588  0.001639            1   0.014436       0
# 3  0.565217  0.474576  0.503375  0.057375            1   0.527521       0
# 4  0.565217  0.474576  0.508277  0.002575            1   0.023041       0
#
#    Monday  Saturday  Sunday  ...  Tactic__2  Tactic__3  Tactic__4  Tactic__5  \
# 0       0         1       0  ...          0          0          0          0
# 1       0         1       0  ...          1          0          0          0
# 2       0         1       0  ...          0          1          0          0
# 3       0         1       0  ...          0          0          1          0
# 4       0         1       0  ...          0          0          0          1
#
# ...

# %%
# if (data_MLP['Tactic__1'] == 1):
#     data_MLP_server1_tactic_1 = data_MLP

data_MLP_server1_tactic_1 = data_MLP[(data_MLP['Tactic__1'] == 1) & (data_MLP['Server__1'] == 1)]
data_MLP_server2_tactic_1 = data_MLP[(data_MLP['Tactic__1'] == 1) & (data_MLP['Server__2'] == 1)]
data_MLP_server3_tactic_1 = data_MLP[(data_MLP['Tactic__1'] == 1) & (data_MLP['Server__3'] == 1)]

data_LSTM_server1_tactic_1 = data_LSTM[(data_LSTM['Tactic__1'] == 1) & (data_LSTM['Server__1'] == 1)]
data_LSTM_server2_tactic_1 = data_LSTM[(data_LSTM['Tactic__1'] == 1) & (data_LSTM['Server__2'] == 1)]
data_LSTM_server3_tactic_1 = data_LSTM[(data_LSTM['Tactic__1'] == 1) & (data_LSTM['Server__3'] == 1)]

data_SVR_RBF_server1_tactic_1 = data_SVR_RBF[(data_LSTM['Tactic__1'] == 1) & (data_SVR_RBF['Server__1'] == 1)]
data_SVR_RBF_server2_tactic_1 = data_SVR_RBF[(data_LSTM['Tactic__1'] == 1) & (data_SVR_RBF['Server__2'] == 1)]
data_SVR_RBF_server3_tactic_1 = data_SVR_RBF[(data_LSTM['Tactic__1'] == 1) & (data_SVR_RBF['Server__3'] == 1)]

# %%
data_MLP_server1_tactic_1
# Out:
#           Hours   Minutes   Seconds   Latency  Reliability  TotalCost  Friday  \
# 10     0.565217  0.491525  0.476137  0.016224            1   0.050864       0
# 25     0.565217  0.525424  0.126337  0.016577            1   0.051389       0
# 40     0.565217  0.542373  0.183827  0.015010            1   0.051290       0
# 55     0.565217  0.559322  0.269270  0.014881            1   0.044559       0
# 70     0.565217  0.576271  0.447305  0.016609            1   0.054411       0
# ...         ...       ...       ...       ...          ...        ...     ...
# 52034  0.782609  0.084746  0.825038  0.015165            1   0.053423       0
# 52049  0.782609  0.118644  0.531408  0.015050            1   0.045065       0
# 52064  0.782609  0.152542  0.524748  0.017436            1   0.054050       0
# 52079  0.782609  0.186441  0.152044  0.017913            1   0.051745       0
# 52094  0.782609  0.203390  0.239083  0.016661            1   0.052235       0
#
# ...

# %%
data_MLP_server2_tactic_1
# Out:
#           Hours   Minutes   Seconds   Latency  Reliability  TotalCost  Friday  \
# 0      0.565217  0.474576  0.330735  0.015461            1   0.031044       0
# 15     0.565217  0.491525  0.759685  0.015274            1   0.029592       0
# 30     0.565217  0.525424  0.410879  0.015464            1   0.027237       0
# 45     0.565217  0.542373  0.477076  0.015264            1   0.031724       0
# 60     0.565217  0.559322  0.709573  0.015262            1   0.034410       0
# ...         ...       ...       ...       ...          ...        ...     ...
# 52024  0.782609  0.067797  0.685751  0.018196            1   0.033331       0
# 52039  0.782609  0.101695  0.313326  0.017969            1   0.031017       0
# 52054  0.782609  0.118644  0.943253  0.017721            1   0.031212       0
# 52069  0.782609  0.152542  0.809777  0.017967            1   0.029747       0
# 52084  0.782609  0.186441  0.444522  0.018177            1   0.033296       0
#
# ...

# %%
data_MLP_server3_tactic_1
# Out:
#           Hours   Minutes   Seconds   Latency  Reliability  TotalCost  Friday  \
# 5      0.565217  0.474576  0.998962  0.101216            1   0.082007       0
# 20     0.565217  0.508475  0.745018  0.067803            1   0.040604       0
# 35     0.565217  0.525424  0.898029  0.087322            1   0.083054       0
# 50     0.565217  0.542373  0.987110  0.068592            1   0.067656       0
# 65     0.565217  0.576271  0.158173  0.061945            1   0.067646       0
# ...         ...       ...       ...       ...          ...        ...     ...
# 52029  0.782609  0.084746  0.534814  0.127348            1   0.085235       0
# 52044  0.782609  0.118644  0.231450  0.222321            1   0.195791       0
# 52059  0.782609  0.152542  0.120167  0.302139            1   0.202225       0
# 52074  0.782609  0.169492  0.857777  0.287419            1   0.182248       0
# 52089  0.782609  0.186441  0.948400  0.053578            1   0.066058       0
#
# ...

# %%
data_MLP_server1_tactic_1.to_csv('data_MLP_server1_tactic_1.csv')
data_MLP_server2_tactic_1.to_csv('data_MLP_server2_tactic_1.csv')
data_MLP_server3_tactic_1.to_csv('data_MLP_server3_tactic_1.csv')

data_LSTM_server1_tactic_1.to_csv('data_LSTM_server1_tactic_1.csv')
data_LSTM_server2_tactic_1.to_csv('data_LSTM_server2_tactic_1.csv')
data_LSTM_server3_tactic_1.to_csv('data_LSTM_server3_tactic_1.csv')

data_SVR_RBF_server1_tactic_1.to_csv('data_SVR_RBF_server1_tactic_1.csv')
data_SVR_RBF_server2_tactic_1.to_csv('data_SVR_RBF_server2_tactic_1.csv')
data_SVR_RBF_server3_tactic_1.to_csv('data_SVR_RBF_server3_tactic_1.csv')

# %%
data_ARIMA = pd.read_csv("predictions_ARIMA.csv")

# %%
data_ARIMA.head()
# Out:
#       Hours   Minutes   Seconds   Latency  Reliability  TotalCost  Friday  \
# 0  0.565217  0.474576  0.330735  0.015461            1   0.031044       0
# 1  0.565217  0.474576  0.391352  0.031939            1   0.295909       0
# 2  0.565217  0.474576  0.394588  0.001639            1   0.014436       0
# 3  0.565217  0.474576  0.503375  0.057375            1   0.527521       0
# 4  0.565217  0.474576  0.508277  0.002575            1   0.023041       0
#
#    Monday  Saturday  Sunday  ...  Tactic__2  Tactic__3  Tactic__4  Tactic__5  \
# 0       0         1       0  ...          0          0          0          0
# 1       0         1       0  ...          1          0          0          0
# 2       0         1       0  ...          0          1          0          0
# 3       0         1       0  ...          0          0          1          0
# 4       0         1       0  ...          0          0          0          1
#
# ...

# %%
data_ARIMA_server1_tactic_1 = data_MLP[(data_ARIMA['Tactic__1'] == 1) & (data_ARIMA['Server__1'] == 1)]
data_ARIMA_server2_tactic_1 = data_MLP[(data_ARIMA['Tactic__1'] == 1) & (data_ARIMA['Server__2'] == 1)]
data_ARIMA_server3_tactic_1 = data_MLP[(data_ARIMA['Tactic__1'] == 1) & (data_ARIMA['Server__3'] == 1)]

# %%
data_ARIMA_server1_tactic_1.to_csv('data_ARIMA_server1_tactic_1.csv')
data_ARIMA_server2_tactic_1.to_csv('data_ARIMA_server2_tactic_1.csv')
data_ARIMA_server3_tactic_1.to_csv('data_ARIMA_server3_tactic_1.csv')
